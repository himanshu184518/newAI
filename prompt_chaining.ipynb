# %%
from langgraph.graph import StateGraph,START,END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
# Out:
# c:\Users\him11\Langgraph\myenv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
load_dotenv()
# Out:
# True

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
model = ChatGroq(model='openai/gpt-oss-120b', temperature=0)

# %%
def create_outline(state:BlogState)->BlogState:
    title=state['title']
    prompt=f'generate an outline for a blog on the topic{title}'
    outline = model.invoke(prompt).content
    state['outline']=outline
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title=state['title']
    
    outline = state['outline']
    prompt=f'write a detailed blog on the {title} using following outline {outline} '
    content=model.invoke(prompt).content
    state['content']=content
    return state

# %%
graph= StateGraph(BlogState)
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow=graph.compile()

# %%
initial_state={'title':'Rise of king kohli'}
final_state=workflow.invoke(initial_state)
print(final_state['outline'])
# Out:
# **Blog Outline – “The Rise of ‘King’ Kohli”**
#
# ---
#
# ### 1. Introduction
# - **Hook:** A vivid snapshot of Kohli’s electrifying presence on the field (e.g., a recent chase or a signature celebration).
# - **Thesis Statement:** How Virat Kohli transformed from a prodigious youngster into one of cricket’s most dominant modern-day monarchs.
#
# ### 2. Early Roots
# - **2.1. Childhood in Delhi** – family background, early love for cricket.
# - **2.2. The Delhi Cricket Academy** – first formal coaching, mentors, and early breakthroughs.
# - **2.3. Under‑19 World Cup Hero (2008)** – performance, leadership glimpses, and the “future of Indian cricket” tag.
#
# ### 3. Domestic & IPL Ascendancy
# - **3.1. Ranji Trophy & First‑Class Success** – stats, key innings, and the “run‑machine” label.
# - **3.2. IPL Debut with Royal Challengers Bangalore (RCB)** – impact, fan following, and the “Kohli‑Killer” reputation.
# - **3.3. Evolution as a Finisher** – analysis of his role in high‑pressure chases.
#
# ### 4. International Breakthrough
# - **4.1. ODI Debut (2011) & Early Struggles** – initial performances, learning curve.
# - **4.2. The 2011‑2014 Turning Point** – series against Australia, England, and the 2014 ICC World T20 triumph.
# - **4.3. Test Debut & the “Kohli Effect”** – first Test, early centuries, and his aggressive batting philosophy.
#
# ### 5. The Crown of Captaincy
# - **5.1. ODI & T20I Captaincy (2017)** – leadership style, key series wins, and the “aggressive captain” tag.
# - **5.2. Test Captaincy (2014‑2022)** – historic overseas series (Australia 2018‑19, England 2021), record‑breaking run‑chases.
# - **5.3. Leadership Philosophy** – fitness emphasis, mental toughness, and “lead by example” ethos.
#
# ### 6. Record‑Breaking Milestones
# - **6.1. Run Tallies & Averages** – fastest to 8,000/9,000/10,000 ODI runs, double centuries in Tests.
# - **6.2. Chase Mastery** – highest successful run‑chases, “run‑chase king” statistics.
# - **6.3. Awards & Honors** – ICC Player of the Year, Padma Shri, Wisden Cricketer of the Year, etc.
#
# ### 7. The Brand “King Kohli”
# - **7.1. Marketability & Endorsements** – major brand partnerships, social‑media influence.
# - **7.2. Philanthropy & Personal Ventures** – foundation work, fashion line, and other business interests.
# - **7.3. Cultural Impact** – how he reshaped Indian cricket fandom, the “Kohli Army” phenomenon.
#
# ### 8. Controversies & Criticisms
# - **8.1. On‑field Aggression** – incidents, media backlash, and how he responded.
# - **8.2. Captaincy Debates** – criticism of selection choices, batting order experiments.
# - **8.3. Personal Life Spotlight** – marriage to Anushka Sharma, media scrutiny, and balancing fame.
#
# ### 9. The Evolution of His Game
# - **9.1. Technical Adjustments** – changes in technique against spin, pace, and in different formats.
# - **9.2. Fitness Revolution** – role of his training regime in extending his dominance.
# - **9.3. Mental Resilience** – coping with pressure, setbacks, and the “never‑settle” mindset.
#
# ### 10. Future Outlook
# - **10.1. Post‑Captaincy Phase** – potential roles, mentorship, and impact on the next generation.
# - **10.2. Longevity in the Modern Game** – how he can stay relevant amid emerging talent.
# - **10.3. Legacy Projection** – where “King Kohli” stands in cricket history compared to legends like Tendulkar, Bradman, and Viv Richards.
#
# ### 11. Conclusion
# - Recap of the key milestones that cemented Kohli’s “kingly” status.
# - Final reflection on what his rise teaches about ambition, discipline, and modern sport leadership.
#
# ### 12. Call‑to‑Action (Optional)
# - Invite readers to share their favorite Kohli moments.
# - Suggest related reads (e.g., “The Science Behind Kohli’s Fitness Regime” or “Top 10 Kohli Chases”).
#
# ---
#
# **Tips for Writing the Blog:**
# - Use vivid anecdotes and match‑specific quotes to bring each phase to life.
# - Incorporate statistics in easy‑to‑read infographics or bullet points.
# - Sprinkle high‑resolution images (e.g., iconic celebrations, trophy lifts).
# - Balance admiration with critical analysis to keep the piece credible and engaging.
